# %%
import pandas as pd
fert = pd.read_csv("/Users/ozlemunal/Desktop/spiced/my_encounter_notes/week_01/data/gapminder_total_fertility.csv", index_col=0)
life = pd.read_excel("/Users/ozlemunal/Desktop/spiced/my_encounter_notes/week_01/data/gapminder_lifeexpectancy.xlsx", index_col=0)
pop = pd.read_excel("/Users/ozlemunal/Desktop/spiced/my_encounter_notes/week_01/data/gapminder_population.xlsx", index_col=0)
continent = pd.read_csv("/Users/ozlemunal/Desktop/spiced/my_encounter_notes/week_01/data/continents.csv", index_col=0, sep = ";")

# %%
fert.shape
# Out:
# (260, 216)

# %%
life.shape
# Out:
# (260, 217)

# %%
pop.shape
# Out:
# (275, 81)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
life = life.drop(2016, axis=1)
life.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2006  2007  2008  2009  2010  2011  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.1  52.4  52.8  53.3  53.6  54.0
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.4  76.6  76.8  77.0  77.2  77.4
# Algeria                28.82  28.82  ...  75.0  75.3  75.5  75.7  76.0  76.1
#
#                        2012  2013  2014  2015
# Life expectancy
# Abkhazia                NaN   NaN   NaN   NaN
# Afghanistan            54.4  54.8  54.9  53.8
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN
# Albania                77.5  77.7  77.9  78.0
# Algeria                76.2  76.3  76.3  76.4
#
# [5 rows x 216 columns]

# %%
fert.columns = fert.columns.astype(int)

# %%
life.columns = life.columns.astype(int)

# %%
pop.columns = pop.columns.astype(int)

# %%
continent.columns
# Out:
# Index(['country'], dtype='object')

# %%
continent.head()
# Out:
#             country
# continent
# Africa      Algeria
# Africa       Angola
# Africa        Benin
# Africa     Botswana
# Africa      Burkina

# %%
type(continent.columns)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
fert.index.name = 'country'
fert.head()
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# country
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# country                      ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
#                        2013  2014  2015
# country
# Abkhazia                NaN   NaN   NaN
# Afghanistan            4.90  4.68  4.47
# Akrotiri and Dhekelia   NaN   NaN   NaN
# Albania                1.77  1.78  1.78
# Algeria                2.80  2.76  2.71
#
# [5 rows x 216 columns]

# %%
life.index.name = "country"
life.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# country
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2006  2007  2008  2009  2010  2011  \
# country                              ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.1  52.4  52.8  53.3  53.6  54.0
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.4  76.6  76.8  77.0  77.2  77.4
# Algeria                28.82  28.82  ...  75.0  75.3  75.5  75.7  76.0  76.1
#
#                        2012  2013  2014  2015
# country
# Abkhazia                NaN   NaN   NaN   NaN
# Afghanistan            54.4  54.8  54.9  53.8
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN
# Albania                77.5  77.7  77.9  78.0
# Algeria                76.2  76.3  76.3  76.4
#
# [5 rows x 216 columns]

# %%
pop.index.name = "country"
pop.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# country
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# country
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
#                        ...        2006        2007        2008        2009  \
# country                ...
# Abkhazia               ...         NaN         NaN         NaN         NaN
# Afghanistan            ...  25183615.0  25877544.0  26528741.0  27207291.0
# Akrotiri and Dhekelia  ...     15700.0     15700.0     15700.0         NaN
# Albania                ...   3050741.0   3010849.0   2968026.0   2929886.0
# Algeria                ...  33749328.0  34261971.0  34811059.0  35401790.0
#
#                              2010        2011        2012        2013  \
# country
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            27962207.0  28809167.0  29726803.0  30682500.0
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                 2901883.0   2886010.0   2880667.0   2883281.0
# Algeria                36036159.0  36717132.0  37439427.0  38186135.0
#
#                              2014        2015
# country
# Abkhazia                      NaN         NaN
# Afghanistan            31627506.0  32526562.0
# Akrotiri and Dhekelia         NaN         NaN
# Albania                 2889676.0   2896679.0
# Algeria                38934334.0  39666519.0
#
# [5 rows x 81 columns]

# %%
fert = fert.reset_index()

# %%
life = life.reset_index()

# %%
pop = pop.reset_index()

# %%
continent = continent.reset_index()

# %%
fert = fert.melt(id_vars='country', var_name='year', value_name='fertility_rate')

# %%
life = life.melt(id_vars='country', var_name='year', value_name='life_expectancy')

# %%
pop = pop.melt(id_vars="country", var_name="year", value_name="population")

# %%
continent.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
life.head()
# Out:
#                  country  year  life_expectancy
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800            28.21
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800            35.40
# 4                Algeria  1800            28.82

# %%
pop.head()
# Out:
#                  country  year  population
# 0               Abkhazia  1800         NaN
# 1            Afghanistan  1800   3280000.0
# 2  Akrotiri and Dhekelia  1800         NaN
# 3                Albania  1800    410445.0
# 4                Algeria  1800   2503218.0

# %%
df = fert.merge(pop)
df = df.merge(life)
df = df.merge(continent)
df.head()
# Out:
#        country  year  fertility_rate  population  life_expectancy continent
# 0  Afghanistan  1800             7.0   3280000.0            28.21      Asia
# 1  Afghanistan  1810             7.0   3280000.0            28.11      Asia
# 2  Afghanistan  1820             7.0   3323519.0            28.01      Asia
# 3  Afghanistan  1830             7.0   3448982.0            27.90      Asia
# 4  Afghanistan  1840             7.0   3625022.0            27.80      Asia

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_subset = df.loc[df['year'] == 2000]
sns.scatterplot(x='life_expectancy', y='fertility_rate',
            data=df_subset, alpha=0.6)
plt.xlim(10, 85)
plt.ylim(1, 9)
# Out:
# (1.0, 9.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_subset = df.loc[df['year'] == 2000]
sns.scatterplot(x='life_expectancy',
                y='fertility_rate',
                hue="continent",
                size = "population",
                sizes=(10, 500),
                data=df_subset,
                alpha=0.6,
               )
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Life Expectancy versus Fertility Rate')
# Set x-axis label
plt.xlabel('Life Expectancy')
# Set y-axis label
plt.ylabel('Fertility Rate')
plt.xlim(10, 85)
plt.ylim(1, 9)
p = plt.subplot()
h,l = p.get_legend_handles_labels()
plt.legend(h[0:7], l[0:7], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.tight_layout
plt.savefig("life_x2.png", bbox_inches='tight')

# %%
subset_df = df[df['year'] > 1959]
subset_df
# Out:
#            country  year  fertility_rate  population  life_expectancy  \
# 25     Afghanistan  1960            7.67   8994793.0            31.94
# 26     Afghanistan  1961            7.67   9164945.0            32.47
# 27     Afghanistan  1962            7.67   9343772.0            33.01
# 28     Afghanistan  1963            7.67   9531555.0            33.53
# 29     Afghanistan  1964            7.67   9728645.0            34.07
# ...            ...   ...             ...         ...              ...
# 14332     Zimbabwe  2011            3.64  14255592.0            51.60
# 14333     Zimbabwe  2012            3.56  14565482.0            54.20
# 14334     Zimbabwe  2013            3.49  14898092.0            55.70
# 14335     Zimbabwe  2014            3.41  15245855.0            57.00
# 14336     Zimbabwe  2015            3.35  15602751.0            59.30
#
#       continent
# 25         Asia
# 26         Asia
# 27         Asia
# 28         Asia
# 29         Asia
# ...         ...
# 14332    Africa
# 14333    Africa
# 14334    Africa
# 14335    Africa
# 14336    Africa
#
# [9912 rows x 6 columns]

# %%
def plot_sns(dataframe):
    sns.scatterplot(
        x='life_expectancy',
        y='fertility_rate',
        data=dataframe,
        hue="continent",
        size = "population",
        sizes=(15, 2000),
        alpha=0.6
    );  
    plt.title('Life Expectancy versus Fertility Rate')
    plt.xlabel('Life Expectancy')
    plt.ylabel('Fertility Rate')
    plt.xlim(10, 85)
    plt.ylim(1, 9)
    #plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    p = plt.subplot()
    h,l = p.get_legend_handles_labels()
    plt.legend(h[0:7], l[0:7], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    plt.tight_layout()

# %%
# To test the function we will subset 2000 
df_2000 = subset_df[subset_df["year"]==2000]

# %%
# Now we will apply it on the that subset
plot_sns(df_2000)
plt.savefig("life_2000.png")

# %% [markdown]
# ** For loop to save all the years in the subset **

# %%
for year in range(1960, 2016):
    cur_subset_df = df[df['year'] == year]
    plot_sns(cur_subset_df)
    plt.savefig(f"output_{year}.png")
    plt.clf()

# %%
pip install imageio
# Out:
# Requirement already satisfied: imageio in /Users/ozlemunal/anaconda3/lib/python3.10/site-packages (2.26.0)
# Requirement already satisfied: numpy in /Users/ozlemunal/anaconda3/lib/python3.10/site-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /Users/ozlemunal/anaconda3/lib/python3.10/site-packages (from imageio) (9.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import imageio.v2

images = []

for i in range(1960, 2016):
    life_gif = 'output_{}.png'.format(i)
    images.append(imageio.v2.imread(life_gif))

imageio.v2.mimsave('life_fun.gif', images, fps=20)
