# %% [markdown]
# # Exercise: Descriptive Statistics

# %% [markdown]
# ### Solve the following with `pandas` one-liners

# %% [markdown]
# **1. read `gapminder_lifeexpectancy.xlsx`**

# %%
import pandas as pd
life_1 = pd.read_excel('/Users/ozlemunal/Desktop/spiced/my_encounter_notes/week_01/data/gapminder_lifeexpectancy.xlsx', index_col=0)

# %% [markdown]
# **2. show the first 3 rows**

# %%
life_1.head(3)
# Out:
#                         1800  1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.2  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
#
# [3 rows x 217 columns]

# %% [markdown]
# **3. filter out all years but 1960 and missing values**

# %%
life = life_1[1960].dropna()
life
# Out:
# Life expectancy
# Afghanistan              31.94
# Albania                  62.87
# Algeria                  47.50
# Angola                   35.98
# Antigua and Barbuda      62.97
#                          ...
# Virgin Islands (U.S.)    63.75
# Yemen                    32.64
# Zambia                   48.34
# Zimbabwe                 53.11
# South Sudan              34.61
# Name: 1960, Length: 202, dtype: float64

# %% [markdown]
# **4. calculate the mean life expectancy**

# %%
life.mean()
# Out:
# 54.73282178217821

# %% [markdown]
# **5. calculate the median**

# %%
life.median()
# Out:
# 56.185

# %% [markdown]
# **6. calculate the standard deviation**

# %%
life.std()
# Out:
# 11.689637178760742

# %% [markdown]
# **7. calculate the variance**

# %%
life.var()
# Out:
# 136.64761737106542

# %% [markdown]
# **8. find the highest life expectancy**

# %%
life.max()
# Out:
# 74.22

# %% [markdown]
# **9. find the lowest life expectancy**

# %%
life.min()
# Out:
# 29.61

# %% [markdown]
# **10. find the 90% quantile**

# %%
life.quantile(0.90)
# Out:
# 69.707

# %% [markdown]
# **11. store the number of data points in a variable**

# %%
life_var=life.value_counts()
life_var
# Out:
# 58.91    2
# 60.08    2
# 31.94    1
# 39.80    1
# 65.60    1
#         ..
# 60.59    1
# 61.24    1
# 46.51    1
# 35.71    1
# 34.61    1
# Name: 1960, Length: 200, dtype: int64

# %% [markdown]
# **12. calculate min, max, mean and range (and possibly other descriptors) with a single line**

# %%
life.describe()
# Out:
# count    202.000000
# mean      54.732822
# std       11.689637
# min       29.610000
# 25%       45.075000
# 50%       56.185000
# 75%       64.742500
# max       74.220000
# Name: 1960, dtype: float64

# %%
life.head()
# Out:
# Life expectancy
# Afghanistan            31.94
# Albania                62.87
# Algeria                47.50
# Angola                 35.98
# Antigua and Barbuda    62.97
# Name: 1960, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
life_1.head()
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#                         1808   1809  ...  2007  2008  2009  2010  2011  2012  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...  52.4  52.8  53.3  53.6  54.0  54.4
# Akrotiri and Dhekelia    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5
# Algeria                28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2
#
#                        2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN    NaN
# Afghanistan            54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN    NaN
# Albania                77.7  77.9  78.0  78.10
# Algeria                76.3  76.3  76.4  76.50
#
# [5 rows x 217 columns]

# %%
life_2 = life_1.dropna()
life_3 = life_2.transpose()
life_3.head(3)
# Out:
# Life expectancy  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  \
# 1800                   28.21     35.4    28.82   26.98                33.54
# 1801                   28.20     35.4    28.82   26.98                33.54
# 1802                   28.19     35.4    28.82   26.98                33.54
#
# Life expectancy  Argentina  Armenia  Aruba  Australia  Austria  ...  Vanuatu  \
# 1800                  33.2     34.0  34.42      34.05     34.4  ...     24.3
# 1801                  33.2     34.0  34.42      34.05     34.4  ...     24.3
# 1802                  33.2     34.0  34.42      34.05     34.4  ...     24.3
#
# Life expectancy  Venezuela  West Bank and Gaza  Western Sahara  Vietnam  \
# 1800                  32.2                32.1           34.75     32.0
# 1801                  32.2                32.1           34.75     32.0
# 1802                  32.2                32.1           34.75     32.0
#
# Life expectancy  Virgin Islands (U.S.)  Yemen  Zambia  Zimbabwe  South Sudan
# 1800                              33.4  23.39    32.6      33.7        26.67
# 1801                              33.4  23.39    32.6      33.7        26.67
# 1802                              33.4  23.39    32.6      33.7        26.67
#
# [3 rows x 201 columns]

# %%
life_3.describe()
# Out:
# Life expectancy  Afghanistan     Albania     Algeria      Angola  \
# count             217.000000  217.000000  217.000000  217.000000
# mean               32.095161   46.694240   39.037051   32.884424
# std                 8.750624   16.326669   16.920052   10.044869
# min                 7.050000   19.430000   11.000000   10.430000
# 25%                27.220000   35.400000   28.820000   26.980000
# 50%                27.760000   35.400000   28.820000   26.980000
# 75%                33.010000   64.840000   48.550000   37.080000
# max                54.900000   78.100000   76.500000   60.000000
#
# Life expectancy  Antigua and Barbuda   Argentina     Armenia       Aruba  \
# count                     217.000000  217.000000  217.000000  217.000000
# mean                       46.233641   48.726728   46.616313   47.112719
# std                        16.738398   16.583004   16.558361   16.667010
# min                        21.750000   32.600000   22.630000   22.320000
# 25%                        33.540000   33.200000   34.000000   34.420000
# 50%                        33.540000   41.760000   36.230000   34.420000
# 75%                        63.930000   65.640000   67.820000   66.440000
# max                        76.500000   76.700000   74.900000   75.850000
#
# Life expectancy   Australia     Austria  ...     Vanuatu   Venezuela  \
# count            217.000000  217.000000  ...  217.000000  217.000000
# mean              54.098341   50.510138  ...   34.654194   44.013548
# std               17.906419   17.371086  ...   15.104681   16.827289
# min               34.050000   31.390000  ...   24.300000   29.140000
# 25%               34.050000   34.400000  ...   24.300000   32.200000
# 50%               54.160000   41.980000  ...   24.300000   32.200000
# 75%               70.790000   69.640000  ...   47.140000   61.300000
# max               82.400000   81.400000  ...   65.100000   74.900000
#
# Life expectancy  West Bank and Gaza  Western Sahara     Vietnam  \
# count                    217.000000      217.000000  217.000000
# mean                      42.548479       39.910829   42.568203
# std                       15.851167       10.234868   16.103019
# min                       26.610000       13.440000   16.870000
# 25%                       32.100000       34.750000   32.000000
# 50%                       32.100000       34.750000   32.000000
# 75%                       52.080000       39.120000   58.350000
# max                       74.700000       68.560000   75.600000
#
# Life expectancy  Virgin Islands (U.S.)       Yemen      Zambia    Zimbabwe  \
# count                       217.000000  217.000000  217.000000  217.000000
# mean                         46.659309   31.628203   38.298571   40.617604
# std                          17.671251   14.550452    9.012150   10.619063
# min                          21.660000   19.390000   12.610000   17.030000
# 25%                          33.400000   23.390000   32.600000   33.700000
# 50%                          33.400000   23.390000   32.600000   33.700000
# 75%                          64.460000   34.520000   45.900000   49.100000
# max                          80.820000   67.100000   57.660000   64.900000
#
# Life expectancy  South Sudan
# count             217.000000
# mean               32.436083
# std                10.091219
# min                10.310000
# 25%                26.670000
# 50%                26.670000
# 75%                35.750000
# max                56.100000
#
# [8 rows x 201 columns]
