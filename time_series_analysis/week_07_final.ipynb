# %% [markdown]
# **Project: Time Series Analysis**

# %%
from dateutil.relativedelta import relativedelta
from scipy.signal import savgol_filter

# %%
# data analysis stack
import numpy as np
import pandas as pd

# data visualization stack
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# machine learning stack
from sklearn.preprocessing import (
    PolynomialFeatures,
    OneHotEncoder
)
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error


# time-related stack
from datetime import datetime as dt

# miscellaneous
import warnings
warnings.filterwarnings("ignore")

# statistics stack
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.stattools import adfuller, kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose

import pmdarima as pm

# %%
def p_values(series):
    """
    returns p-values for ADF and KPSS Tests on a time series
    """
    # p value from Augmented Dickey-Fuller (ADF) Test
    p_adf = adfuller(series, autolag="AIC")[1]
    
    # p value from Kwiatkowski–Phillips–Schmidt–Shin (KPSS) Test
    p_kpss = kpss(series, regression="c", nlags="auto")[1]
    
    return round(p_adf,6), round(p_kpss,6)

# %%
def test_stationarity(series):
    """
    returns likely conclusions about series stationarity
    """
    # test heteroscedasticity with qcd
    qcd = qcd_variance(series)
    
    if qcd >= 0.50:
        print(f"\n non-stationary: heteroscedastic (qcd = {qcd}) \n")
    
    # test stationarity
    else:
        p_adf, p_kpss = p_values(series)
        
        # print p-values
        print( f"\n p_adf: {p_adf}, p_kpss: {p_kpss}" )
    
        if (p_adf < 0.01) and (p_kpss >= 0.05):
            print('\n stationary or seasonal-stationary')
            
        elif (p_adf >= 0.1) and (p_kpss < 0.05):
            print('\n difference-stationary')
            
        elif (p_adf < 0.1) and (p_kpss < 0.05):
            print('\n trend-stationary')
        
        else:
            print('\n non-stationary; no robust conclusions\n')

# %%
def auto_correlation_plot(series):
    """
    plots autocorrelations for a given series
    """
    mpl.rc('figure',figsize=(10,2),dpi=200)
    plot_acf(series,zero=False,lags=25)
    plt.xlabel('number of lags')
    plt.ylabel('autocorrelation')

# %%
def partial_auto_correlation_plot(series):
    """
    plots partial autocorrelations for a given series
    """
    mpl.rc('figure',figsize=(10,2),dpi=200)
    plot_pacf(series,zero=False,lags=25)
    plt.xlabel('number of lags')
    plt.ylabel('partial autocorrelation')

# %% [markdown]
# **Loading data**

# %% [markdown]
# EUROPEAN CLIMATE ASSESSMENT & DATASET (ECA&D), file created on 08-05-2023
# THESE DATA CAN BE USED FREELY PROVIDED THAT THE FOLLOWING SOURCE IS ACKNOWLEDGED:
#
# Klein Tank, A.M.G. and Coauthors, 2002. Daily dataset of 20th-century surface
# air temperature and precipitation series for the European Climate Assessment.
# Int. J. of Climatol., 22, 1441-1453.
# Data and metadata available at http://www.ecad.eu
#
# FILE FORMAT (MISSING VALUE CODE IS -9999):
#
# 01-06 SOUID: Source identifier
# 08-15 DATE : Date YYYYMMDD
# 17-21 TG   : mean temperature in 0.1 &#176;C
# 23-27 Q_TG : Quality code for TG (0='valid'; 1='suspect'; 9='missing')
#
# This is the blended series of station GERMANY, BERLIN-TEMPELHOF (STAID: 2759).
# Blended and updated with sources: 111448 127488 128124
# See file sources.txt and stations.txt for more info.

# %%
# load  txt file as a dataframe

df = pd.read_csv(
    "./data/TG_STAID002759.txt",
    # data starts from line 20
    skiprows = 19,
    # remove empty space in column name
    skipinitialspace = True,
    # parse DATE column 1
    parse_dates = [1],
)

# %%
df.tail()
# Out:
#         SOUID       DATE   TG  Q_TG
# 53776  111448 2023-03-27   34     0
# 53777  111448 2023-03-28   35     0
# 53778  111448 2023-03-29   66     0
# 53779  111448 2023-03-30  117     0
# 53780  111448 2023-03-31  108     0

# %%
# Missing data will be filled with the mean of 5 years of preceding and 5 years of following data points.

# %%
df_missing = df[df["Q_TG"]==9]

# %%
df_missing["DATE"].min()
# Out:
# Timestamp('1945-04-25 00:00:00')

# %%
df_missing["DATE"].max()
# Out:
# Timestamp('1945-11-05 00:00:00')

# %%
missing_days = (df_missing["DATE"].max()-df_missing["DATE"].min()).days + 1
missing_days
# Out:
# 195

# %%
missing_days == df_missing.shape[0]
# Out:
# True

# %%
# reference years are all years 5 years before and  5 years after
reference_years = list(range(-5,6))
reference_years.remove(0)
# function for clean temperature values
def clean_temp(df,x):
    """
    returns a temperaure column in celcius with missing values imputed;
    imputation is done with the average of the temperautes on the same
    day over all the reference years; division by 10 for celcius value
    """
    # if missing value occurs
    if x['Q_TG']==9:
        # list reference dates
        reference_dates = [x['DATE']+relativedelta(years=y) for y in reference_years]
        # mean temperatue over the references dates
        temp_value = df[df['DATE'].isin(reference_dates)]['TG'].mean()
        # division by 10 to convert to celcius value
        return int(temp_value)/10
    # else just division by 10 to convert to celcius value
    return x['TG']/10

# %%
# create clean temperatutre column
df['TEMP'] = df.apply(
    lambda x: clean_temp(df,x),
    axis=1
)

# %%
df.isna().count()
# Out:
# SOUID    53781
# DATE     53781
# TG       53781
# Q_TG     53781
# TEMP     53781
# dtype: int64

# %%
df.shape
# Out:
# (53781, 5)

# %%
df.columns=df.columns.str.lower()
clean_df=df.set_index("date")[["temp"]]

# %%
clean_df.head(20)
# Out:
#             temp
# date
# 1876-01-01   2.2
# 1876-01-02   2.5
# 1876-01-03   0.3
# 1876-01-04  -5.8
# 1876-01-05  -9.8
# 1876-01-06  -7.7
# 1876-01-07  -6.6
# 1876-01-08  -8.9
# 1876-01-09 -12.7
# 1876-01-10  -8.9
# 1876-01-11  -6.2
# 1876-01-12  -4.6
# 1876-01-13  -3.5
# 1876-01-14  -3.6
# 1876-01-15  -3.1
# 1876-01-16  -2.3
# 1876-01-17  -1.2
# 1876-01-18   0.8
# 1876-01-19   3.8
# 1876-01-20   3.3

# %%
# Data is splited from the beginning to 2022-12-31. Last 3 monts will be the test data
train= clean_df[:"2022-12-31"]
test= clean_df["2023-01-01":]

# %%
train.shape
# Out:
# (53691, 1)

# %%
test.shape
# Out:
# (90, 1)

# %%
#train.to_csv("./data/train.csv")
#test.to_csv("./data/test.csv")

# %%
# plot the last 5 years
train_last_five = train["2017-01-01":]

mpl.rc('figure',figsize=(12,3),dpi=100)

train_last_five['temp'].plot(legend=True)
sns.despine()

# %%
# savitzky-golary filter will be used to filter the noise
train['denoised'] = savgol_filter(np.array(train['temp']), 99, 3, mode = 'nearest')
train['noise'] = train['temp'] - train['denoised']

# %%
print(train['denoised'])
# Out:
# date
# 1876-01-01   -0.659391
# 1876-01-02   -0.772946
# 1876-01-03   -0.858296
# 1876-01-04   -1.025494
# 1876-01-05   -1.151521
#                 ...
# 2022-12-27    6.827954
# 2022-12-28    7.212065
# 2022-12-29    7.611574
# 2022-12-30    8.021626
# 2022-12-31    8.411407
# Name: denoised, Length: 53691, dtype: float64

# %%
# plot the last 5 years
train_denoised_five = train["2017-01-01":]

mpl.rc('figure', figsize=(12,3), dpi=100)

train_denoised_five[['temp', 'denoised']].plot(legend=True)
sns.despine()

# %% [markdown]
# # DENOISED DATA

# %%
train.head()
# Out:
#             temp  denoised     noise
# date
# 1876-01-01   2.2 -0.659391  2.859391
# 1876-01-02   2.5 -0.772946  3.272946
# 1876-01-03   0.3 -0.858296  1.158296
# 1876-01-04  -5.8 -1.025494 -4.774506
# 1876-01-05  -9.8 -1.151521 -8.648479

# %%
train['timestep'] = list(range(train.shape[0]))

# %% [markdown]
# **Trend Model**

# %%
X_trend_denoised = train[['timestep']]
y_trend_denoised = train['denoised']

# %%
X_trend_denoised.shape
# Out:
# (53691, 1)

# %%
# trend model for denoised data 
trend_model_de = make_pipeline(
    PolynomialFeatures(degree=2),
    LinearRegression()
)

# %%
trend_model_de.fit(X_trend_denoised,y_trend_denoised)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
train['trend_pred'] = trend_model_de.predict(X_trend_denoised)
train['trend_pred']
# Out:
# date
# 1876-01-01     9.234793
# 1876-01-02     9.234747
# 1876-01-03     9.234700
# 1876-01-04     9.234653
# 1876-01-05     9.234606
#                 ...
# 2022-12-27    11.085904
# 2022-12-28    11.086020
# 2022-12-29    11.086135
# 2022-12-30    11.086251
# 2022-12-31    11.086367
# Name: trend_pred, Length: 53691, dtype: float64

# %%
mpl.rc('figure',figsize=(12,3),dpi=100)

train[['denoised','trend_pred']]["2017-01-01":].plot(legend=True)
sns.despine()

# %%
train.head()
# Out:
#             temp  denoised     noise  timestep  trend_pred
# date
# 1876-01-01   2.2 -0.659391  2.859391         0    9.234793
# 1876-01-02   2.5 -0.772946  3.272946         1    9.234747
# 1876-01-03   0.3 -0.858296  1.158296         2    9.234700
# 1876-01-04  -5.8 -1.025494 -4.774506         3    9.234653
# 1876-01-05  -9.8 -1.151521 -8.648479         4    9.234606

# %% [markdown]
# **Seasonality model**

# %%
train['detrended_de'] = train['denoised'] - train['trend_pred']

# %%
mpl.rc('figure',figsize=(12,3),dpi=100)

train['detrended_de']["2017-01-01":].plot(legend=True)
sns.despine()

# %%
train["day_of_year"] = train.index.dayofyear

# %%
train.head()
# Out:
#             temp  denoised     noise  timestep  trend_pred  detrended_de
# date
# 1876-01-01   2.2 -0.659391  2.859391         0    9.234793     -9.894184  \
# 1876-01-02   2.5 -0.772946  3.272946         1    9.234747    -10.007693
# 1876-01-03   0.3 -0.858296  1.158296         2    9.234700    -10.092996
# 1876-01-04  -5.8 -1.025494 -4.774506         3    9.234653    -10.260147
# 1876-01-05  -9.8 -1.151521 -8.648479         4    9.234606    -10.386128
#
#             day_of_year
# date
# 1876-01-01            1
# 1876-01-02            2
# 1876-01-03            3
# 1876-01-04            4
# 1876-01-05            5

# %%
X_seasonality_de = train[['day_of_year']]
y_seasonality_de = train['detrended_de']

# %%
# seasonality model
seasonality_model = make_pipeline(
    OneHotEncoder(drop='first'),
    LinearRegression()
)

# %%
seasonality_model.fit(X_seasonality_de, y_seasonality_de)
# Out:
# Pipeline(steps=[('onehotencoder', OneHotEncoder(drop='first')),
#                 ('linearregression', LinearRegression())])

# %%
train['seasonality_pred'] = seasonality_model.predict(X_seasonality_de)
train['seasonality_pred']
# Out:
# date
# 1876-01-01   -9.067679
# 1876-01-02   -9.103861
# 1876-01-03   -9.141828
# 1876-01-04   -9.176523
# 1876-01-05   -9.206905
#                 ...
# 2022-12-27   -8.820279
# 2022-12-28   -8.848868
# 2022-12-29   -8.883836
# 2022-12-30   -8.922330
# 2022-12-31   -8.965668
# Name: seasonality_pred, Length: 53691, dtype: float64

# %%
#add something to plot just last 5 years.
mpl.rc('figure',figsize=(12,3),dpi=100)

train[['detrended_de','seasonality_pred']]["2017-01-01":].plot(legend=True)
sns.despine()

# %%
train.tail()
# Out:
#             temp  denoised     noise  timestep  trend_pred  detrended_de
# date
# 2022-12-27   4.2  6.827954 -2.627954     53686   11.085904     -4.257950  \
# 2022-12-28   6.3  7.212065 -0.912065     53687   11.086020     -3.873954
# 2022-12-29  10.0  7.611574  2.388426     53688   11.086135     -3.474561
# 2022-12-30   7.6  8.021626 -0.421626     53689   11.086251     -3.064625
# 2022-12-31  14.8  8.411407  6.388593     53690   11.086367     -2.674959
#
#             day_of_year  seasonality_pred  trend_seasonal_pred  remainder_de
# date
# 2022-12-27          361         -8.820279             2.265625      4.562329  \
# 2022-12-28          362         -8.848868             2.237152      4.974914
# 2022-12-29          363         -8.883836             2.202300      5.409274
# 2022-12-30          364         -8.922330             2.163921      5.857705
# 2022-12-31          365         -8.965668             2.120699      6.290709
#
#             remainder_pred  noise_pred  over_all_pred
# date
# 2022-12-27        4.449352    2.959906       9.674883
# 2022-12-28        4.869442   -3.032289       4.074304
# 2022-12-29        5.308826   -0.066639       7.444487
# 2022-12-30        5.757806    2.118865      10.040592
# 2022-12-31        6.216933   -0.885694       7.451937

# %%
# combine trend and seasonality

train['trend_seasonal_pred'] = train['trend_pred'] + train['seasonality_pred']

mpl.rc('figure',figsize=(12,3),dpi=100)
train[['denoised','trend_seasonal_pred']]["2017-01-01":].plot(legend=True)
sns.despine()

# %% [markdown]
# **REMAINDER**

# %%
train['remainder_de'] = train['denoised'] - train['trend_seasonal_pred']

# %%
def qcd_variance(series,window=12):
    """
    This function returns the quartile coefficient of dispersion
    of the rolling variance of a series in a given window range 
    """
    # rolling variance for a given window 
    variances = series.rolling(window).var().dropna()
    # first quartile
    Q1 = np.percentile(variances, 25, interpolation='midpoint')
    # third quartile
    Q3 = np.percentile(variances, 75, interpolation='midpoint')
    # quartile coefficient of dispersion 
    qcd = round((Q3-Q1)/(Q3+Q1),6)
    
    print(f"quartile coefficient of dispersion: {qcd}")

# %%
# quartile coefficient of dispersion
qcd_variance(train['remainder_de'])
# Out:
# quartile coefficient of dispersion: 0.756349

# %%
#temp_remainder = train['remainder_de'].reset_index()
#temp_remainder.to_csv('./data/temp_remainder.csv',index=False)

# %%
#df = pd.read_csv("./data/temp_remainder.csv").set_index('date')
#df.tail()

# %%
mpl.rc('figure',figsize=(12,3),dpi=100)

train['remainder_de']["2017-01-01":].plot(legend=True)
sns.despine()

# %%
arima_model_remainder = pm.auto_arima(
    train['remainder_de'],
    seasonality = False,
    stationarity = False,
    d=None,
    trace = True,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=-155910.608, Time=27.66 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=211090.848, Time=0.96 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=inf, Time=8.77 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=138235.240, Time=10.16 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=211088.848, Time=0.47 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=-142583.534, Time=20.00 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=-155759.746, Time=18.59 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=-155027.318, Time=73.26 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=-156154.934, Time=24.95 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=-147878.158, Time=19.50 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=-156272.400, Time=56.53 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=-156315.840, Time=19.79 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=-155433.955, Time=184.20 sec
#  ARIMA(5,0,3)(0,0,0)[0] intercept   : AIC=-156324.427, Time=32.78 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=176.72 sec
#  ARIMA(5,0,4)(0,0,0)[0] intercept   : AIC=-156313.780, Time=103.74 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=-156296.401, Time=30.66 sec
#  ARIMA(5,0,3)(0,0,0)[0]             : AIC=-156326.998, Time=18.41 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=-156321.099, Time=32.86 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=inf, Time=44.07 sec
#  ARIMA(5,0,4)(0,0,0)[0]             : AIC=-156320.937, Time=28.33 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=-155439.618, Time=29.12 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=-156301.630, Time=29.60 sec
#
# Best model:  ARIMA(5,0,3)(0,0,0)[0]
# Total fit time: 991.165 seconds

# %%
arima_model_remainder.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                53691
# Model:               SARIMAX(5, 0, 3)   Log Likelihood               78172.499
# Date:                Sun, 14 May 2023   AIC                        -156326.998
# Time:                        16:56:34   BIC                        -156246.979
# Sample:                    01-01-1876   HQIC                       -156302.015
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.8416      0.216      8.518      0.000       1.418       2.265
# ar.L2         -0.7932      0.453     -1.751      0.080      -1.681       0.095
# ar.L3          0.3174      0.338      0.940      0.347      -0.345       0.980
# ar.L4         -0.6738      0.296     -2.280      0.023      -1.253      -0.095
# ar.L5          0.3064      0.107      2.853      0.004       0.096       0.517
# ma.L1         -0.1091      0.216     -0.505      0.614      -0.533       0.314
# ma.L2         -0.0927      0.134     -0.693      0.489      -0.355       0.170
# ma.L3         -0.4453      0.145     -3.068      0.002      -0.730      -0.161
# sigma2         0.0032   8.33e-06    381.819      0.000       0.003       0.003
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           3434870.61
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.03   Skew:                            -1.68
# Prob(H) (two-sided):                  0.05   Kurtosis:                        42.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#arima_model_remainder.fit(train["remainder_de"])

# %%
#train["remainder_pred1"].forecast(3)

# %%
train["remainder_pred"]=arima_model_remainder.predict_in_sample()
train
# Out:
#             temp  denoised     noise  timestep  trend_pred  detrended_de
# date
# 1876-01-01   2.2 -0.659391  2.859391         0    9.234793     -9.894184  \
# 1876-01-02   2.5 -0.772946  3.272946         1    9.234747    -10.007693
# 1876-01-03   0.3 -0.858296  1.158296         2    9.234700    -10.092996
# 1876-01-04  -5.8 -1.025494 -4.774506         3    9.234653    -10.260147
# 1876-01-05  -9.8 -1.151521 -8.648479         4    9.234606    -10.386128
# ...          ...       ...       ...       ...         ...           ...
# 2022-12-27   4.2  6.827954 -2.627954     53686   11.085904     -4.257950
# 2022-12-28   6.3  7.212065 -0.912065     53687   11.086020     -3.873954
# 2022-12-29  10.0  7.611574  2.388426     53688   11.086135     -3.474561
# 2022-12-30   7.6  8.021626 -0.421626     53689   11.086251     -3.064625
# 2022-12-31  14.8  8.411407  6.388593     53690   11.086367     -2.674959
#
#             day_of_year  seasonality_pred  trend_seasonal_pred  remainder_de
# date
# 1876-01-01            1         -9.067679             0.167114     -0.826505  \
# 1876-01-02            2         -9.103861             0.130886     -0.903832
# 1876-01-03            3         -9.141828             0.092872     -0.951168
# 1876-01-04            4         -9.176523             0.058131     -1.083625
# 1876-01-05            5         -9.206905             0.027701     -1.179223
# ...                 ...               ...                  ...           ...
# 2022-12-27          361         -8.820279             2.265625      4.562329
# 2022-12-28          362         -8.848868             2.237152      4.974914
# 2022-12-29          363         -8.883836             2.202300      5.409274
# 2022-12-30          364         -8.922330             2.163921      5.857705
# 2022-12-31          365         -8.965668             2.120699      6.290709
#
#             remainder_pred
# date
# 1876-01-01        0.000000
# 1876-01-02       -0.825196
# 1876-01-03       -0.963962
# 1876-01-04       -0.989624
# 1876-01-05       -1.184407
# ...                    ...
# 2022-12-27        4.449352
# 2022-12-28        4.869442
# 2022-12-29        5.308826
# 2022-12-30        5.757806
# 2022-12-31        6.216933
#
# [53691 rows x 11 columns]

# %% [markdown]
# **NOISE**

# %%
arima_model_noise = pm.auto_arima(
    train['noise'],
    seasonality = False,
    stationarity = True,
    d=None,
    trace = True,
    n_jobs=-1
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=236170.934, Time=11.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=281014.350, Time=0.82 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=237947.817, Time=1.63 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=248842.149, Time=4.08 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=281012.360, Time=0.45 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=236168.405, Time=3.97 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=240177.652, Time=6.20 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=236167.313, Time=4.68 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=236168.317, Time=9.97 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=236244.516, Time=2.69 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=236165.314, Time=1.48 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=248840.154, Time=1.46 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=237945.817, Time=0.56 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=236166.318, Time=3.12 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=236166.406, Time=1.50 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=240175.655, Time=2.27 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=236242.517, Time=1.41 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=236168.935, Time=4.32 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[0]
# Total fit time: 61.697 seconds

# %%
#arima_model_noise.fit(train["noise"])

# %%
arima_model_noise.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                53691
# Model:               SARIMAX(1, 0, 1)   Log Likelihood             -118079.657
# Date:                Sun, 14 May 2023   AIC                         236165.314
# Time:                        16:57:36   BIC                         236191.987
# Sample:                    01-01-1876   HQIC                        236173.642
#                          - 12-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6375      0.004    159.291      0.000       0.630       0.645
# ma.L1          0.2428      0.005     47.709      0.000       0.233       0.253
# sigma2         4.7616      0.026    185.205      0.000       4.711       4.812
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              1036.54
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.00   Skew:                            -0.07
# Prob(H) (two-sided):                  0.97   Kurtosis:                         3.67
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train["noise_pred"]=arima_model_noise.predict_in_sample()
train.tail(10)
# Out:
#             temp  denoised     noise  timestep  trend_pred  detrended_de
# date
# 2022-12-22   7.2  5.339386  1.860614     53681   11.085325     -5.745940  \
# 2022-12-23   6.5  5.609907  0.890093     53682   11.085441     -5.475534
# 2022-12-24   6.5  5.905126  0.594874     53683   11.085557     -5.180430
# 2022-12-25   4.9  6.197579 -1.297579     53684   11.085673     -4.888093
# 2022-12-26   9.5  6.480916  3.019084     53685   11.085788     -4.604872
# 2022-12-27   4.2  6.827954 -2.627954     53686   11.085904     -4.257950
# 2022-12-28   6.3  7.212065 -0.912065     53687   11.086020     -3.873954
# 2022-12-29  10.0  7.611574  2.388426     53688   11.086135     -3.474561
# 2022-12-30   7.6  8.021626 -0.421626     53689   11.086251     -3.064625
# 2022-12-31  14.8  8.411407  6.388593     53690   11.086367     -2.674959
#
#             day_of_year  seasonality_pred  trend_seasonal_pred  remainder_de
# date
# 2022-12-22          356         -8.595419             2.489907      2.849479  \
# 2022-12-23          357         -8.652029             2.433412      3.176495
# 2022-12-24          358         -8.707686             2.377871      3.527256
# 2022-12-25          359         -8.754053             2.331619      3.865960
# 2022-12-26          360         -8.789350             2.296438      4.184478
# 2022-12-27          361         -8.820279             2.265625      4.562329
# 2022-12-28          362         -8.848868             2.237152      4.974914
# 2022-12-29          363         -8.883836             2.202300      5.409274
# 2022-12-30          364         -8.922330             2.163921      5.857705
# 2022-12-31          365         -8.965668             2.120699      6.290709
#
#             remainder_pred  noise_pred
# date
# 2022-12-22        2.809851    0.862119
# 2022-12-23        3.142612    1.428675
# 2022-12-24        3.450361    0.436690
# 2022-12-25        3.817745    0.417667
# 2022-12-26        4.147900   -1.243761
# 2022-12-27        4.449352    2.959906
# 2022-12-28        4.869442   -3.032289
# 2022-12-29        5.308826   -0.066639
# 2022-12-30        5.757806    2.118865
# 2022-12-31        6.216933   -0.885694

# %% [markdown]
# **FINALLY**

# %%
train['over_all_pred'] = (train['trend_pred'] + train['seasonality_pred'] + train["remainder_pred"] + train["noise_pred"])

# %%
train['over_all_pred']
# Out:
# date
# 1876-01-01     0.167114
# 1876-01-02     1.429791
# 1876-01-03     1.485498
# 1876-01-04    -0.483452
# 1876-01-05    -5.468660
#                 ...
# 2022-12-27     9.674883
# 2022-12-28     4.074304
# 2022-12-29     7.444487
# 2022-12-30    10.040592
# 2022-12-31     7.451937
# Name: over_all_pred, Length: 53691, dtype: float64

# %%
train.tail()
# Out:
#             temp  denoised     noise  timestep  trend_pred  detrended_de
# date
# 2022-12-27   4.2  6.827954 -2.627954     53686   11.085904     -4.257950  \
# 2022-12-28   6.3  7.212065 -0.912065     53687   11.086020     -3.873954
# 2022-12-29  10.0  7.611574  2.388426     53688   11.086135     -3.474561
# 2022-12-30   7.6  8.021626 -0.421626     53689   11.086251     -3.064625
# 2022-12-31  14.8  8.411407  6.388593     53690   11.086367     -2.674959
#
#             day_of_year  seasonality_pred  trend_seasonal_pred  remainder_de
# date
# 2022-12-27          361         -8.820279             2.265625      4.562329  \
# 2022-12-28          362         -8.848868             2.237152      4.974914
# 2022-12-29          363         -8.883836             2.202300      5.409274
# 2022-12-30          364         -8.922330             2.163921      5.857705
# 2022-12-31          365         -8.965668             2.120699      6.290709
#
#             remainder_pred  noise_pred  over_all_pred
# date
# 2022-12-27        4.449352    2.959906       9.674883
# 2022-12-28        4.869442   -3.032289       4.074304
# 2022-12-29        5.308826   -0.066639       7.444487
# 2022-12-30        5.757806    2.118865      10.040592
# 2022-12-31        6.216933   -0.885694       7.451937

# %%
#train["remainder_pred"].forecast(3)

# %% [markdown]
# **TEST DATA PREDICTIONS**

# %%
test_df = pd.read_csv("./data/test.csv", index_col=0)
test_df
# Out:
#             temp
# date
# 2023-01-01  14.5
# 2023-01-02  13.1
# 2023-01-03   5.6
# 2023-01-04   7.1
# 2023-01-05   8.2
# ...          ...
# 2023-03-27   3.4
# 2023-03-28   3.5
# 2023-03-29   6.6
# 2023-03-30  11.7
# 2023-03-31  10.8
#
# [90 rows x 1 columns]

# %%
test["day_of_year"] = test.index.dayofyear 
test['timestep'] = list(range(test.shape[0]))
test['timestep'] += max(train['timestep']) + 1
test
# Out:
#             temp  day_of_year  timestep  trend_pred  seasonality_pred
# date
# 2023-01-01  14.5            1     53691   11.086482         -9.067679  \
# 2023-01-02  13.1            2     53692   11.086598         -9.103861
# 2023-01-03   5.6            3     53693   11.086714         -9.141828
# 2023-01-04   7.1            4     53694   11.086830         -9.176523
# 2023-01-05   8.2            5     53695   11.086945         -9.206905
# ...          ...          ...       ...         ...               ...
# 2023-03-27   3.4           86     53776   11.096329         -3.748413
# 2023-03-28   3.5           87     53777   11.096445         -3.590867
# 2023-03-29   6.6           88     53778   11.096561         -3.433318
# 2023-03-30  11.7           89     53779   11.096677         -3.274031
# 2023-03-31  10.8           90     53780   11.096793         -3.110674
#
#             remainder_pred  noise_pred  over_all_pred
# date
# 2023-01-01             NaN         NaN            NaN
# 2023-01-02             NaN         NaN            NaN
# 2023-01-03             NaN         NaN            NaN
# 2023-01-04             NaN         NaN            NaN
# 2023-01-05             NaN         NaN            NaN
# ...                    ...         ...            ...
# 2023-03-27             NaN         NaN            NaN
# 2023-03-28             NaN         NaN            NaN
# 2023-03-29             NaN         NaN            NaN
# 2023-03-30             NaN         NaN            NaN
# 2023-03-31             NaN         NaN            NaN
#
# [90 rows x 8 columns]

# %%
X_trend_test = test[['timestep']]
test["trend_pred"] = trend_model_de.predict(X_trend_test)
test
# Out:
#             temp  day_of_year  timestep  trend_pred  seasonality_pred
# date
# 2023-01-01  14.5            1     53691   11.086482         -9.067679  \
# 2023-01-02  13.1            2     53692   11.086598         -9.103861
# 2023-01-03   5.6            3     53693   11.086714         -9.141828
# 2023-01-04   7.1            4     53694   11.086830         -9.176523
# 2023-01-05   8.2            5     53695   11.086945         -9.206905
# ...          ...          ...       ...         ...               ...
# 2023-03-27   3.4           86     53776   11.096329         -3.748413
# 2023-03-28   3.5           87     53777   11.096445         -3.590867
# 2023-03-29   6.6           88     53778   11.096561         -3.433318
# 2023-03-30  11.7           89     53779   11.096677         -3.274031
# 2023-03-31  10.8           90     53780   11.096793         -3.110674
#
#             remainder_pred  noise_pred  over_all_pred
# date
# 2023-01-01             NaN         NaN            NaN
# 2023-01-02             NaN         NaN            NaN
# 2023-01-03             NaN         NaN            NaN
# 2023-01-04             NaN         NaN            NaN
# 2023-01-05             NaN         NaN            NaN
# ...                    ...         ...            ...
# 2023-03-27             NaN         NaN            NaN
# 2023-03-28             NaN         NaN            NaN
# 2023-03-29             NaN         NaN            NaN
# 2023-03-30             NaN         NaN            NaN
# 2023-03-31             NaN         NaN            NaN
#
# [90 rows x 8 columns]

# %%
test["day_of_year"] = test.index.dayofyear
X_seasonality_test = test[["day_of_year"]]
test["seasonality_pred"] = seasonality_model.predict(X_seasonality_test)

# %%
arima_model_remainder.predict()
# Out:
# 2023-01-01    6.639445
# 2023-01-02    6.925022
# 2023-01-03    7.161180
# 2023-01-04    7.358769
# 2023-01-05    7.523676
# 2023-01-06    7.660039
# 2023-01-07    7.771462
# 2023-01-08    7.860066
# 2023-01-09    7.927575
# 2023-01-10    7.975633
# Freq: D, dtype: float64

# %%
test["remainder_pred"] = arima_model_remainder.predict(90)
test.shape
# Out:
# (90, 8)

# %%
test["noise_pred"] = arima_model_noise.predict(90)
test
# Out:
#             temp  day_of_year  timestep  trend_pred  seasonality_pred
# date
# 2023-01-01  14.5            1     53691   11.086482         -9.067679  \
# 2023-01-02  13.1            2     53692   11.086598         -9.103861
# 2023-01-03   5.6            3     53693   11.086714         -9.141828
# 2023-01-04   7.1            4     53694   11.086830         -9.176523
# 2023-01-05   8.2            5     53695   11.086945         -9.206905
# ...          ...          ...       ...         ...               ...
# 2023-03-27   3.4           86     53776   11.096329         -3.748413
# 2023-03-28   3.5           87     53777   11.096445         -3.590867
# 2023-03-29   6.6           88     53778   11.096561         -3.433318
# 2023-03-30  11.7           89     53779   11.096677         -3.274031
# 2023-03-31  10.8           90     53780   11.096793         -3.110674
#
#             remainder_pred    noise_pred  over_all_pred
# date
# 2023-01-01        6.639445  5.839353e+00            NaN
# 2023-01-02        6.925022  3.722824e+00            NaN
# 2023-01-03        7.161180  2.373452e+00            NaN
# 2023-01-04        7.358769  1.513172e+00            NaN
# 2023-01-05        7.523676  9.647083e-01            NaN
# ...                    ...           ...            ...
# 2023-03-27       -0.388396  1.411011e-16            NaN
# 2023-03-28       -0.420412  8.995769e-17            NaN
# 2023-03-29       -0.449904  5.735167e-17            NaN
# 2023-03-30       -0.476954  3.656402e-17            NaN
# 2023-03-31       -0.501640  2.331105e-17            NaN
#
# [90 rows x 8 columns]

# %%
test['over_all_pred'] = (test['trend_pred'] + test['seasonality_pred'] + test["remainder_pred"] + test["noise_pred"])
test['over_all_pred']
# Out:
# date
# 2023-01-01    14.497601
# 2023-01-02    12.630583
# 2023-01-03    11.479518
# 2023-01-04    10.782248
# 2023-01-05    10.368425
#                 ...
# 2023-03-27     6.959521
# 2023-03-28     7.085167
# 2023-03-29     7.213339
# 2023-03-30     7.345693
# 2023-03-31     7.484479
# Name: over_all_pred, Length: 90, dtype: float64

# %%
test
# Out:
#             temp  day_of_year  timestep  trend_pred  seasonality_pred
# date
# 2023-01-01  14.5            1     53691   11.086482         -9.067679  \
# 2023-01-02  13.1            2     53692   11.086598         -9.103861
# 2023-01-03   5.6            3     53693   11.086714         -9.141828
# 2023-01-04   7.1            4     53694   11.086830         -9.176523
# 2023-01-05   8.2            5     53695   11.086945         -9.206905
# ...          ...          ...       ...         ...               ...
# 2023-03-27   3.4           86     53776   11.096329         -3.748413
# 2023-03-28   3.5           87     53777   11.096445         -3.590867
# 2023-03-29   6.6           88     53778   11.096561         -3.433318
# 2023-03-30  11.7           89     53779   11.096677         -3.274031
# 2023-03-31  10.8           90     53780   11.096793         -3.110674
#
#             remainder_pred    noise_pred  over_all_pred
# date
# 2023-01-01        6.639445  5.839353e+00      14.497601
# 2023-01-02        6.925022  3.722824e+00      12.630583
# 2023-01-03        7.161180  2.373452e+00      11.479518
# 2023-01-04        7.358769  1.513172e+00      10.782248
# 2023-01-05        7.523676  9.647083e-01      10.368425
# ...                    ...           ...            ...
# 2023-03-27       -0.388396  1.411011e-16       6.959521
# 2023-03-28       -0.420412  8.995769e-17       7.085167
# 2023-03-29       -0.449904  5.735167e-17       7.213339
# 2023-03-30       -0.476954  3.656402e-17       7.345693
# 2023-03-31       -0.501640  2.331105e-17       7.484479
#
# [90 rows x 8 columns]

# %%
mpl.rc('figure',figsize=(12,3),dpi=100)

test[['temp',"over_all_pred"]].plot(legend=True)
sns.despine()
