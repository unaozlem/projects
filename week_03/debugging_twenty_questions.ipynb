# %%
import json

# %%
def is_answer(node):
    return len(node) == 1

# %%
f = open('questions.json')
json.load(f)
# Out:
# {'text': 'Can it fly?',
#  'yes': {'text': 'Does it have feathers?',
#   'yes': {'text': 'Does it sometimes live in water?',
#    'yes': {'text': 'Does it eat fish?',
#     'yes': {'text': 'Does it have long legs?',
#      'yes': {'text': 'Is it pink?',
#       'yes': {'text': 'Does it look weird to humans?',
#        'yes': {'text': 'Does it sometimes stand on one leg?',
#         'yes': {'text': "It's not pink or stands on one leg is it?",
#          'yes': {'text': 'Is it some kind of jelly fish?',
#           'yes': {'text': 'Does it have legs?',
#            'yes': {'text': 'Is it not real?',
#             'yes': {'text': 'Are you going to keep hitting yes?',
#              'yes': {'text': 'Does it have stripes?',
#               'yes': {'text': 'Is it white?',
#                'yes': {'text': 'Is it a male?',
#                 'yes': {'text': 'Is it yellow?',
#                  'yes': {'text': 'Is it related to the cat family?',
# ...

# %%
content = f.read

# %%
node = json.reads(content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 node = json.reads(content)
#
# AttributeError: module 'json' has no attribute 'reads'

# %%
finished = False

while not finished:
    print(node['text'])
    if is_answer_node(node):
        finished = True
    else:
        answer == input()
        if answer.upper() in ['yes', 'y']:
            node = node['no']
        else:
            node = node['yes']
